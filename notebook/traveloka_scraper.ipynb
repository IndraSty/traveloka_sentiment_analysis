# %%
pip install google-play-scraper

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
# Menyimpan ulasan dalam file CSV
import csv
import pandas as pd  # Pandas untuk manipulasi dan analisis data

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews(
    'com.traveloka.android',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=30000        # Jumlah maksimum ulasan yang ingin diambil
)

# %%
review_list, token = scrapreview

# %%
with open('traveloka_assessment.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in review_list:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
app_reviews_df = pd.DataFrame(scrapreview[0])
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('traveloka_assessment.csv', index=False)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
jumlah_ulasan
# Out:
# 5

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId               userName  \
# 0  af30f2ac-4fe4-4342-980e-705eef4a8603  Fadilla Permata Putri
# 1  f126ca9b-c0f5-4dc3-9222-695cbc31a4e3      debora nugrahaeni
# 2  8408ca37-2b90-4c21-8327-7c651654ee1e          Ardianto Adam
# 3  9bac52bc-6462-4fda-98ca-03aa38cd683a               Della fr
# 4  cb97cf21-32e2-49e5-8320-7e9effc4bca6     Nurhalimah Sijabat
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Aku suka banget booking hotel, atraksi sampai ...      5             21
# 1  Travelokasi aplikasi yang paling praktis, inte...      5             13
# ...

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              5 non-null      object
#  1   userName              5 non-null      object
#  2   userImage             5 non-null      object
#  3   content               5 non-null      object
#  4   score                 5 non-null      int64
#  5   thumbsUpCount         5 non-null      int64
#  6   reviewCreatedVersion  5 non-null      object
#  7   at                    5 non-null      datetime64[ns]
#  8   replyContent          5 non-null      object
#  9   repliedAt             5 non-null      datetime64[ns]
#  10  appVersion            5 non-null      object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 572.0+ bytes
